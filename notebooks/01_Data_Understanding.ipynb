# %% [markdown]
# # Predictive Forecasting of Care Load & Placement Demand
#
# ## U.S. Department of Health and Human Services (HHS)
#
# ### Notebook 01: Data Understanding
#
# ---
#
# ### Project Objective
#
# The objective of this notebook is to perform the initial understanding of the Unaccompanied Alien Children (UAC) dataset. This includes loading the dataset, understanding its structure, identifying variables, checking data quality, and preparing the foundation for Exploratory Data Analysis (EDA) and predictive forecasting.
#
# ---
#
# ### Author
#
# Kishan Masura
#
# ---
#
# ### Notebook Goals
#
# - Load the dataset
# - Understand each column
# - Verify data types
# - Check dataset dimensions
# - Identify missing values
# - Generate descriptive statistics
# - Prepare for Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np

# %%
# ==========================================
# Load Dataset
# ==========================================

import pandas as pd

df = pd.read_csv("../data/raw/HHS_Unaccompanied_Alien_Children_Program.csv")

df.head()
# Out:
#                 Date  Children apprehended and placed in CBP custody*  \
# 0  December 21, 2025                                              6.0
# 1  December 18, 2025                                             11.0
# 2  December 17, 2025                                              7.0
# 3  December 16, 2025                                              8.0
# 4  December 15, 2025                                             11.0
#
#    Children in CBP custody  Children transferred out of CBP custody  \
# 0                     18.0                                     11.0
# 1                     50.0                                      6.0
# 2                     31.0                                     11.0
# 3                     54.0                                     15.0
# 4                     42.0                                      9.0
#
#   Children in HHS Care  Children discharged from HHS Care
# 0                2,484                               14.0
# ...

# %% [markdown]
# # Predictive Forecasting of Care Load & Placement Demand
#
# ## Notebook 01 – Data Understanding
#
# ### Objective
#
# Understand the dataset before performing any cleaning or analysis.
#
# Tasks:
#
# - View dataset
# - Understand shape
# - Check data types
# - Identify missing values
# - Review summary statistics

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw/HHS_Unaccompanied_Alien_Children_Program.csv")

df.head()
# Out:
#                 Date  Children apprehended and placed in CBP custody*  \
# 0  December 21, 2025                                              6.0
# 1  December 18, 2025                                             11.0
# 2  December 17, 2025                                              7.0
# 3  December 16, 2025                                              8.0
# 4  December 15, 2025                                             11.0
#
#    Children in CBP custody  Children transferred out of CBP custody  \
# 0                     18.0                                     11.0
# 1                     50.0                                      6.0
# 2                     31.0                                     11.0
# 3                     54.0                                     15.0
# 4                     42.0                                      9.0
#
#   Children in HHS Care  Children discharged from HHS Care
# 0                2,484                               14.0
# ...

# %%
df.shape
# Out:
# (1170, 6)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1170 entries, 0 to 1169
# Data columns (total 6 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Date                                             720 non-null    str
#  1   Children apprehended and placed in CBP custody*  720 non-null    float64
#  2   Children in CBP custody                          720 non-null    float64
#  3   Children transferred out of CBP custody          720 non-null    float64
#  4   Children in HHS Care                             720 non-null    str
#  5   Children discharged from HHS Care                720 non-null    float64
# dtypes: float64(4), str(2)
# memory usage: 55.0 KB

# %%
df.describe()
# Out:
#        Children apprehended and placed in CBP custody*  \
# count                                       720.000000
# mean                                         93.523611
# std                                          72.646625
# min                                           0.000000
# 25%                                          12.000000
# 50%                                          99.000000
# 75%                                         147.250000
# max                                         333.000000
#
#        Children in CBP custody  Children transferred out of CBP custody  \
# count               720.000000                               720.000000
# mean                171.494444                               128.668056
# std                 126.354965                                97.322012
# min                   7.000000                                 0.000000
# 25%                  36.000000                                14.000000
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Children apprehended and placed in CBP custody*',
#        'Children in CBP custody', 'Children transferred out of CBP custody',
#        'Children in HHS Care', 'Children discharged from HHS Care'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Date                                                   str
# Children apprehended and placed in CBP custody*    float64
# Children in CBP custody                            float64
# Children transferred out of CBP custody            float64
# Children in HHS Care                                   str
# Children discharged from HHS Care                  float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Date                                               450
# Children apprehended and placed in CBP custody*    450
# Children in CBP custody                            450
# Children transferred out of CBP custody            450
# Children in HHS Care                               450
# Children discharged from HHS Care                  450
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(449)

# %%
df.sample(10)
# Out:
#                    Date  Children apprehended and placed in CBP custody*  \
# 316  September 10, 2024                                            131.0
# 491   December 27, 2023                                             74.0
# 611       June 29, 2023                                             81.0
# 251   December 12, 2024                                            153.0
# 620       June 15, 2023                                             91.0
# 338     August 06, 2024                                            163.0
# 912                 NaN                                              NaN
# 623       June 12, 2023                                             84.0
# 481    January 11, 2024                                             29.0
# 773                 NaN                                              NaN
#
#      Children in CBP custody  Children transferred out of CBP custody  \
# 316                    251.0                                    180.0
# ...

# %%
df[df.isnull().all(axis=1)]
# Out:
#      Date  Children apprehended and placed in CBP custody*  \
# 720   NaN                                              NaN
# 721   NaN                                              NaN
# 722   NaN                                              NaN
# 723   NaN                                              NaN
# 724   NaN                                              NaN
# ...   ...                                              ...
# 1165  NaN                                              NaN
# 1166  NaN                                              NaN
# 1167  NaN                                              NaN
# 1168  NaN                                              NaN
# 1169  NaN                                              NaN
#
#       Children in CBP custody  Children transferred out of CBP custody  \
# 720                       NaN                                      NaN
# 721                       NaN                                      NaN
# ...
